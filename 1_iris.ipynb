# %% [markdown]
# <a href="https://colab.research.google.com/github/Romi74/Buscador-Alquileres-Python/blob/master/1_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://www.inove.com.ar"><img src="https://raw.githubusercontent.com/InoveAlumnos/dataset_analytics_python/master/images/PA%20Banner.png" width="1000" align="center"></a>
#
#
# # Visualización y limpieza con Pandas
#
# Visualización de los datos del dataset iris\
# v1.1

# %% [markdown]
# <a href="https://www.inove.com.ar"><img src="https://raw.githubusercontent.com/InoveAlumnos/dataset_analytics_python/master/iris_dataset.png" width="1000" align="center"></a>

# %%
import os
import platform

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from  sklearn import  datasets

# %% [markdown]
# # Recolectar datos
# <div align="center"><img src="https://raw.githubusercontent.com/InoveAlumnos/dataset_analytics_python/master/images/Pipeline1.png" width="1000" align="middle"></div>

# %%
iris=datasets.load_iris()
df_data = pd.DataFrame(data= iris.data, columns= iris.feature_names)
df_target = pd.DataFrame(data= iris.target, columns= ['species'])
print(df_data.head())
print(df_target.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# # Sección nueva

# %%
# Generar una copia de df_target llamada "df_target_categorical" en el cual se almacenará los tipos de iris como variables categóricas (texto)
df_target_categorical = df_target.copy()

# %% [markdown]
# # Procesar datos
# <div align="center"><img src="https://raw.githubusercontent.com/InoveAlumnos/dataset_analytics_python/master/images/Pipeline2.png" width="1000" align="middle"></div>

# %%
# Alumno: Utilizar apply y lambda expresion sobre df_target para modificar la columna "species" de df_target_categorical
# la lambda debe devolver:
# setosa --> si species = 0
# versicolor --> si species = 1
# virginica --> si species = 2
# Tip:
# df_target_categorical['species'] = df_target.apply(lambda......

# %%
from pandas.core import apply
df_target_categorical["species"]= df_target.apply(lambda x:"setosa" if x.species==0 else "versicolor" if x.species==1 else "virginica", axis=1 )

# %%
# Alumno: Observar las primeras filas del nuevo df_target_categorical para corroborar que haya sido correcto el cambio
df_target_categorical.head()
# Out:
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
from itertools import count
# Alumno: Contar cuantas especies de iris hay de cada una en el dataset df_target_categorical
df_target= df_target.describe()
df_target_categorical["species"].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
# Concatenar ambos dataset
df = pd.concat([df_data, df_target_categorical], axis= 1)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Alumno: Analice si hay elementos incompletos en el dataset "df_data"
df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
# Alumno: ¿Cuántas filas/datos hay para analizar?
# print(....)
print("cantidad de datos para analizar: ",df_data.shape[0])
# Out:
# cantidad de datos para analizar:  150

# %% [markdown]
# # Explorar datos
# <div align="center"><img src="https://raw.githubusercontent.com/InoveAlumnos/dataset_analytics_python/master/images/Pipeline3.png" width="1000" align="middle"></div>

# %%
# Alumno, separe el dataset "df" en un dataset por tipo de iris
# df_setosa = ...
# df_versicolor = ...
# df_verginica = ...

df_setosa=df[df["species"]=="setosa"]
df_virginica=df[df["species"]=="virginica"]
df_versicolor=df[df["species"]=="versicolor"]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 106                4.9               2.5                4.5               1.7
# 107                7.3               2.9                6.3               1.8
# 108                6.7               2.5                5.8               1.8
# 109                7.2               3.6                6.1               2.5
# 110                6.5               3.2                5.1               2.0
# 111                6.4               2.7                5.3               1.9
# 112                6.8               3.0                5.5               2.1
# 113                5.7               2.5                5.0               2.0
# 114                5.8               2.8                5.1               2.4
# 115                6.4               3.2                5.3               2.3
# 116                6.5               3.0                5.5               1.8
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 119                6.0               2.2                5.0               1.5
# 120                6.9               3.2                5.7               2.3
# 121                5.6               2.8                4.9               2.0
# 122                7.7               2.8                6.7               2.0
# 123                6.3               2.7                4.9               1.8
# 124                6.7               3.3                5.7               2.1
# 125                7.2               3.2                6.0               1.8
# 126                6.2               2.8                4.8               1.8
# 127                6.1               3.0                4.9               1.8
# 128                6.4               2.8                5.6               2.1
# 129                7.2               3.0                5.8               1.6
# 130                7.4               2.8                6.1               1.9
# 131                7.9               3.8                6.4               2.0
# 132                6.4               2.8                5.6               2.2
# 133                6.3               2.8                5.1               1.5
# 134                6.1               2.6                5.6               1.4
# 135                7.7               3.0                6.1               2.3
# 136                6.3               3.4                5.6               2.4
# 137                6.4               3.1                5.5               1.8
# 138                6.0               3.0                4.8               1.8
# 139                6.9               3.1                5.4               2.1
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 100  virginica
# 101  virginica
# 102  virginica
# 103  virginica
# 104  virginica
# 105  virginica
# 106  virginica
# 107  virginica
# 108  virginica
# 109  virginica
# 110  virginica
# 111  virginica
# 112  virginica
# 113  virginica
# 114  virginica
# 115  virginica
# 116  virginica
# 117  virginica
# 118  virginica
# 119  virginica
# 120  virginica
# 121  virginica
# 122  virginica
# 123  virginica
# 124  virginica
# 125  virginica
# 126  virginica
# 127  virginica
# 128  virginica
# 129  virginica
# 130  virginica
# 131  virginica
# 132  virginica
# 133  virginica
# 134  virginica
# 135  virginica
# 136  virginica
# 137  virginica
# 138  virginica
# 139  virginica
# 140  virginica
# 141  virginica
# 142  virginica
# 143  virginica
# 144  virginica
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %%
from pandas.core.window.expanding import Axis
# Almuno: Realizar una función que reciba un dataframe como parámetro y grafique
# la relación (scatter plot) entre "petal length (cm)" (x) y "petal width (cm)" (y) de la especie setosa
df_setosa.plot.scatter(x=["petal length (cm)"], y=["petal width (cm)"],color="b")
plt.show()

# %%
# Almuno: Utilizar la función generada para graficar la relación con dada dataframe de cada especie
df_virginica.plot.scatter(x=["petal length (cm)"], y=["petal width (cm)"],color="b")
plt.show()

# %%
df_versicolor.plot.scatter(x=["petal length (cm)"], y=["petal width (cm)"],color="b")
plt.show()
